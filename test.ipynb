# %%
import pandas as pd

# Load Parquet file
df = pd.read_parquet("test-00000-of-00001.parquet")

df
# Out:
#          qid     video_id                                      question_type  \
# 0     0008-0  sj81PWrerDk                        Primary Open-ended Question
# 1     0008-1  sj81PWrerDk                    Paraphrased Open-ended Question
# 2     0008-2  sj81PWrerDk                  Correctly-led Open-ended Question
# 3     0008-3  sj81PWrerDk                    Wrongly-led Open-ended Question
# 4     0008-7  sj81PWrerDk  Multiple-choice Question with a Single Correct...
# ...      ...          ...                                                ...
# 1495  1344-0  eLJNa61S4RE                        Primary Open-ended Question
# 1496  1344-1  eLJNa61S4RE                    Paraphrased Open-ended Question
# 1497  1344-2  eLJNa61S4RE                  Correctly-led Open-ended Question
# 1498  1344-3  eLJNa61S4RE                    Wrongly-led Open-ended Question
# 1499  1344-7  eLJNa61S4RE  Multiple-choice Question with a Single Correct...
#
#                         capability  \
# 0         Plot Attribute (Montage)
# 1         Plot Attribute (Montage)
# 2         Plot Attribute (Montage)
# 3         Plot Attribute (Montage)
# 4         Plot Attribute (Montage)
# ...                            ...
# 1495  Character Reaction Causality
# 1496  Character Reaction Causality
# 1497  Character Reaction Causality
# 1498  Character Reaction Causality
# 1499  Character Reaction Causality
#
#                                                question duration  \
# 0     What is the difference between the action of t...     8.85
# 1     Can you describe how the actions of the last p...     8.85
# 2     Did the last person open the bottle without us...     8.85
# 3     Did the last person in the video open the bott...     8.85
# 4     How does the last person in the video open the...     8.85
# ...                                                 ...      ...
# 1495  In this video, why does the child smile after ...    18.35
# 1496  What causes the child to smile after receiving...    18.35
# 1497  Does the child smile after the injection becau...    18.35
# 1498  Is the child's smile after the injection due t...    18.35
# 1499  Why does the child smile after the injection?\...    18.35
#
#                                         question_prompt answer  \
# 0     Please state your answer with a brief explanat...
# 1     Please state your answer with a brief explanat...
# 2     Please state your answer with a brief explanat...
# 3     Please state your answer with a brief explanat...
# 4     E. None of the above\nSelect one best answer t...
# ...                                                 ...    ...
# 1495  Please state your answer with a brief explanat...
# 1496  Please state your answer with a brief explanat...
# 1497  Please state your answer with a brief explanat...
# 1498  Please state your answer with a brief explanat...
# 1499  E. None of the above\nSelect one best answer t...
#
#                                      youtube_url
# 0     https://www.youtube.com/shorts/sj81PWrerDk
# 1     https://www.youtube.com/shorts/sj81PWrerDk
# 2     https://www.youtube.com/shorts/sj81PWrerDk
# 3     https://www.youtube.com/shorts/sj81PWrerDk
# 4     https://www.youtube.com/shorts/sj81PWrerDk
# ...                                          ...
# 1495  https://www.youtube.com/shorts/eLJNa61S4RE
# 1496  https://www.youtube.com/shorts/eLJNa61S4RE
# 1497  https://www.youtube.com/shorts/eLJNa61S4RE
# 1498  https://www.youtube.com/shorts/eLJNa61S4RE
# 1499  https://www.youtube.com/shorts/eLJNa61S4RE
#
# [1500 rows x 9 columns]

# %%
temp_df = df[df["youtube_url"].str.contains("tT2ldpZHek", na=False)]
temp_df
# Out:
#          qid     video_id                                      question_type  \
# 1470  1312-0  _tT2ldpZHek                        Primary Open-ended Question
# 1471  1312-1  _tT2ldpZHek                    Paraphrased Open-ended Question
# 1472  1312-2  _tT2ldpZHek                  Correctly-led Open-ended Question
# 1473  1312-3  _tT2ldpZHek                    Wrongly-led Open-ended Question
# 1474  1312-7  _tT2ldpZHek  Multiple-choice Question with a Single Correct...
#
#                   capability  \
# 1470  Displacement Attribute
# 1471  Displacement Attribute
# 1472  Displacement Attribute
# 1473  Displacement Attribute
# 1474  Displacement Attribute
#
#                                                question duration  \
# 1470  Is the treadmill running while the person in t...    46.34
# 1471  Was the treadmill active while the person was ...    46.34
# 1472  Did the person in the video have to crawl forw...    46.34
# 1473  Was the treadmill belt stationary while the pe...    46.34
# 1474  What was the state of the treadmill while the ...    46.34
#
#                                         question_prompt answer  \
# 1470  Please state your answer with a brief explanat...
# 1471  Please state your answer with a brief explanat...
# 1472  Please state your answer with a brief explanat...
# 1473  Please state your answer with a brief explanat...
# 1474  E. None of the above\nSelect one best answer t...
#
#                                      youtube_url
# 1470  https://www.youtube.com/shorts/_tT2ldpZHek
# 1471  https://www.youtube.com/shorts/_tT2ldpZHek
# 1472  https://www.youtube.com/shorts/_tT2ldpZHek
# 1473  https://www.youtube.com/shorts/_tT2ldpZHek
# 1474  https://www.youtube.com/shorts/_tT2ldpZHek

# %%
import torch
from transformers import AutoProcessor, Idefics3ForConditionalGeneration
from PIL import Image
import cv2
import numpy as np
from typing import List
import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

class VideoFrameExtractor:
    def __init__(self, max_frames: int = 50):
        self.max_frames = max_frames
        
    def resize_and_center_crop(self, image: Image.Image, target_size: int) -> Image.Image:
        # Get current dimensions
        width, height = image.size
        
        # Calculate new dimensions keeping aspect ratio
        if width < height:
            new_width = target_size
            new_height = int(height * (target_size / width))
        else:
            new_height = target_size
            new_width = int(width * (target_size / height))
            
        # Resize
        image = image.resize((new_width, new_height), Image.Resampling.LANCZOS)
        
        # Center crop
        left = (new_width - target_size) // 2
        top = (new_height - target_size) // 2
        right = left + target_size
        bottom = top + target_size
        
        return image.crop((left, top, right, bottom))
        
    def extract_frames(self, video_path: str) -> List[Image.Image]:
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            raise ValueError(f"Could not open video: {video_path}")
            
        # Get video properties
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        
        # Calculate frame indices to extract (1fps)
        frame_indices = list(range(0, total_frames, fps))
        
        # If we have more frames than max_frames, sample evenly
        if len(frame_indices) > self.max_frames:
            indices = np.linspace(0, len(frame_indices) - 1, self.max_frames, dtype=int)
            frame_indices = [frame_indices[i] for i in indices]
        
        frames = []
        for frame_idx in frame_indices:
            cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
            ret, frame = cap.read()
            if ret:
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                pil_image = Image.fromarray(frame)
                pil_image = self.resize_and_center_crop(pil_image, 384)
                frames.append(pil_image)
        
        cap.release()
        return frames

def load_model(checkpoint_path: str, base_model_id: str = "HuggingFaceTB/SmolVLM-Instruct", device: str = "cuda"):
    # Load processor from original model
    processor = AutoProcessor.from_pretrained(base_model_id)
    if checkpoint_path:
        # Load fine-tuned model from checkpoint
        model = Idefics3ForConditionalGeneration.from_pretrained(
            checkpoint_path,
            torch_dtype=torch.bfloat16,
            device_map=device
        )
    else:
        model = Idefics3ForConditionalGeneration.from_pretrained(
            base_model_id,
            torch_dtype=torch.bfloat16,
            device_map=device
        )    

    # Configure processor for video frames
    processor.image_processor.size = (384, 384)
    processor.image_processor.do_resize = False
    processor.image_processor.do_image_splitting = False
    
    return model, processor

def generate_response(model, processor, video_path: str, question: str, max_frames: int = 50):
    # Extract frames
    frame_extractor = VideoFrameExtractor(max_frames)
    frames = frame_extractor.extract_frames(video_path)
    logger.info(f"Extracted {len(frames)} frames from video")
    
    # Create prompt with frames
    image_tokens = [{"type": "image"} for _ in range(len(frames))]
    messages = [
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "Answer briefly."},
                *image_tokens,
                {"type": "text", "text": question}
            ]
        }
    ]

    # Process inputs
    inputs = processor(
        text=processor.apply_chat_template(messages, add_generation_prompt=True),
        images=[img for img in frames],
        return_tensors="pt"
    ).to(model.device)

    # Generate response
    outputs = model.generate(
        **inputs,
        max_new_tokens=100,
        num_beams=5,
        temperature=0.7,
        do_sample=True,
        use_cache=True
    )
    
    # Decode response
    response = processor.decode(outputs[0], skip_special_tokens=True)
    return response

def main():
    # Configuration
    #checkpoint_path = "/path/to/your/checkpoint"
    checkpoint_path = None
    base_model_id = "HuggingFaceTB/SmolVLM-Instruct"  
    video_path = "/path/to/video.mp4"
    question = "Describe the video"

    device = "cuda" if torch.cuda.is_available() else "cpu"
    
    # Load model
    logger.info("Loading model...")
    model, processor = load_model(checkpoint_path, base_model_id, device)
    
    # Generate response
    logger.info("Generating response...")
    response = generate_response(model, processor, video_path, question)
    
    # Print results
    print("Question:", question)
    print("Response:", response)

if __name__ == "__main__":
    main()

# %%
from transformers import AutoProcessor, AutoModelForImageTextToText
import torch

model_path = "HuggingFaceTB/SmolVLM2-500M-Instruct"

processor = AutoProcessor.from_pretrained(model_path)
model = AutoModelForImageTextToText.from_pretrained(
    model_path,
    torch_dtype=torch.float16,  # Change from bfloat16 to float16
).to("mps")

# Prepare your input data
messages = [
    {
        "role": "user",
        "content": [
            {"type": "video", "path": "Benchmark-AllVideos-HQ-Encoded-challenge/_tT2ldpZHek.mp4"},
            {"type": "text", "text": "What is the man doing in each frame?"}
        ]
    },
]

inputs = processor.apply_chat_template(
    messages,
    add_generation_prompt=True,
    tokenize=True,
    return_dict=True,
    return_tensors="pt",
)

# Fix: Only cast float tensors to float16, leave integer tensors as long
inputs = {
    key: (value.to("mps").to(torch.float16) if value.dtype in [torch.float, torch.float32] else value.to("mps"))
    for key, value in inputs.items()
}

# Generate output
generated_ids = model.generate(**inputs, do_sample=False, max_new_tokens=64)

# Decode and print result
generated_texts = processor.batch_decode(
    generated_ids,
    skip_special_tokens=True,
)
print(generated_texts[0])

# %%
from datasets import load_dataset

ds = load_dataset(path="HuggingFaceTB/smoltalk", name="everyday-conversations")

# %%
ds

# %%
import pandas as pd

# Convert train dataset to a DataFrame
df_train = pd.DataFrame(ds['train'])
df_test = pd.DataFrame(ds['test'])

df_train

# %%
df_test
