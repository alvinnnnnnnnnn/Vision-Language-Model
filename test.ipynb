# %%
import pandas as pd

# Load Parquet file
df = pd.read_parquet("test-00000-of-00001.parquet")

mask = df["question_prompt"].str.contains("E. None of the above", na=False)

# Append "E. None of the above" on a new line to "question"
df.loc[mask, "question"] = df["question"] + "\nE. None of the above"

# Remove only "E. None of the above" from "question_prompt" while keeping the rest
df.loc[mask, "question_prompt"] = df["question_prompt"].str.replace("E. None of the above", "", regex=False).str.strip()

df
# Out:
#          qid     video_id                                      question_type  \
# 0     0008-0  sj81PWrerDk                        Primary Open-ended Question
# 1     0008-1  sj81PWrerDk                    Paraphrased Open-ended Question
# 2     0008-2  sj81PWrerDk                  Correctly-led Open-ended Question
# 3     0008-3  sj81PWrerDk                    Wrongly-led Open-ended Question
# 4     0008-7  sj81PWrerDk  Multiple-choice Question with a Single Correct...
# ...      ...          ...                                                ...
# 1495  1344-0  eLJNa61S4RE                        Primary Open-ended Question
# 1496  1344-1  eLJNa61S4RE                    Paraphrased Open-ended Question
# 1497  1344-2  eLJNa61S4RE                  Correctly-led Open-ended Question
# 1498  1344-3  eLJNa61S4RE                    Wrongly-led Open-ended Question
# 1499  1344-7  eLJNa61S4RE  Multiple-choice Question with a Single Correct...
#
#                         capability  \
# 0         Plot Attribute (Montage)
# 1         Plot Attribute (Montage)
# 2         Plot Attribute (Montage)
# 3         Plot Attribute (Montage)
# 4         Plot Attribute (Montage)
# ...                            ...
# 1495  Character Reaction Causality
# 1496  Character Reaction Causality
# 1497  Character Reaction Causality
# 1498  Character Reaction Causality
# 1499  Character Reaction Causality
#
#                                                question duration  \
# 0     What is the difference between the action of t...     8.85
# 1     Can you describe how the actions of the last p...     8.85
# 2     Did the last person open the bottle without us...     8.85
# 3     Did the last person in the video open the bott...     8.85
# 4     How does the last person in the video open the...     8.85
# ...                                                 ...      ...
# 1495  In this video, why does the child smile after ...    18.35
# 1496  What causes the child to smile after receiving...    18.35
# 1497  Does the child smile after the injection becau...    18.35
# 1498  Is the child's smile after the injection due t...    18.35
# 1499  Why does the child smile after the injection?\...    18.35
#
#                                         question_prompt answer  \
# 0     Please state your answer with a brief explanat...
# 1     Please state your answer with a brief explanat...
# 2     Please state your answer with a brief explanat...
# 3     Please state your answer with a brief explanat...
# 4     Select one best answer to the above multiple-c...
# ...                                                 ...    ...
# 1495  Please state your answer with a brief explanat...
# 1496  Please state your answer with a brief explanat...
# 1497  Please state your answer with a brief explanat...
# 1498  Please state your answer with a brief explanat...
# 1499  Select one best answer to the above multiple-c...
#
#                                      youtube_url
# 0     https://www.youtube.com/shorts/sj81PWrerDk
# 1     https://www.youtube.com/shorts/sj81PWrerDk
# 2     https://www.youtube.com/shorts/sj81PWrerDk
# 3     https://www.youtube.com/shorts/sj81PWrerDk
# 4     https://www.youtube.com/shorts/sj81PWrerDk
# ...                                          ...
# 1495  https://www.youtube.com/shorts/eLJNa61S4RE
# 1496  https://www.youtube.com/shorts/eLJNa61S4RE
# 1497  https://www.youtube.com/shorts/eLJNa61S4RE
# 1498  https://www.youtube.com/shorts/eLJNa61S4RE
# 1499  https://www.youtube.com/shorts/eLJNa61S4RE
#
# [1500 rows x 9 columns]

# %%
import torch
import pandas as pd
import numpy as np
import cv2
import os
from PIL import Image
from transformers import AutoProcessor, AutoModelForVision2Seq

# Select device (CUDA → MPS → CPU)
if torch.cuda.is_available():
    DEVICE = "cuda"
elif torch.backends.mps.is_available():
    DEVICE = "mps"
else:
    DEVICE = "cpu"

# Force CPU if needed
DEVICE = "cpu"

# Define video folder
video_folder = "Benchmark-AllVideos-HQ-Encoded-challenge"

# Load model and processor
processor = AutoProcessor.from_pretrained("HuggingFaceTB/SmolVLM-500M-Instruct")
model = AutoModelForVision2Seq.from_pretrained(
    "HuggingFaceTB/SmolVLM-500M-Instruct",
    torch_dtype=torch.float16 if DEVICE == "mps" else torch.bfloat16,
    _attn_implementation="flash_attention_2" if DEVICE == "cuda" else "eager",
).to(DEVICE)

# Function to extract video frames
def extract_frames(video_path, max_frames=5, target_size=384):  # Reduce max frames to 5
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError(f"Could not open video: {video_path}")

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    
    # Extract frames at 1 FPS
    frame_indices = list(range(0, total_frames, fps))
    
    # If too many frames, evenly sample max_frames
    if len(frame_indices) > max_frames:
        frame_indices = [frame_indices[i] for i in np.linspace(0, len(frame_indices) - 1, max_frames, dtype=int)]
    
    frames = []
    for frame_idx in frame_indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
        ret, frame = cap.read()
        if ret:
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert to RGB
            pil_image = Image.fromarray(frame).resize((target_size, target_size))
            frames.append(pil_image)

    cap.release()
    return frames

for file in os.listdir(video_folder):
    video_path = os.path.join(video_folder, file)

    video_name = os.path.splitext(file)[0]  # Remove file extension
    video_name = video_name.lstrip("_")  # Remove leading underscore

    temp_df = df[df["youtube_url"].str.contains(video_name, na=False)]
    print(f"Matched rows: {len(temp_df)}")

    for index, row in temp_df.iterrows():
        # Extract frames from video
        max_frames = 5  # Limit to 5 images
        frames = extract_frames(video_path, max_frames)

        # Ensure the prompt contains the same number of `` tokens as the number of frames
        image_tokens = " " * len(frames)

        # Truncate the question prompt if too long
        MAX_TEXT_LENGTH = 500  # Set a max length for text input
        question_text = f"{row['question']}\n{row['question_prompt']}"[:MAX_TEXT_LENGTH]

        # Construct the input question with `` tokens
        full_prompt = f"{image_tokens}\n{question_text}"

        # Prepare inputs WITHOUT using chat template
        inputs = processor(
            text=[full_prompt],  # Pass the question with  tokens
            images=frames,  # Pass extracted video frames
            return_tensors="pt",
            truncation=False,  # Prevent unwanted truncation
            max_length=2048,  # Enforce max token length
        )

        # Debug tensor shapes before feeding into model
        print(f"Input IDs Shape: {inputs['input_ids'].shape}")
        print(f"Pixel Values Shape: {inputs['pixel_values'].shape}")

        # Move to correct device and ensure float16 conversion for MPS
        if DEVICE == "mps":
            inputs = {
                key: (value.to(DEVICE).to(torch.float16) if value.dtype in [torch.float, torch.float32] else value.to(DEVICE))
                for key, value in inputs.items()
            }
        else:
            inputs = {key: value.to(DEVICE) for key, value in inputs.items()}

        # Generate output
        generated_ids = model.generate(
            **inputs,
            max_new_tokens=150,  # Reduce max generation length
            repetition_penalty=1.2,  # Avoid repeating words
        )

        # Decode and clean response
        response = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
        response = response.replace(question_text, "").strip()  # Remove repeated question text

        # Print final output
        print(f"Question: {row['question']}\n{row['question_prompt']}")
        print(f"Answer: {response}\n")
# Out:
# Matched rows: 5
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 101
#      98     inputs = {key: value.to(DEVICE) for key, value in inputs.items()}
#     100 # Generate output
# --> 101 generated_ids = model.generate(
#     102     **inputs,
#     103     max_new_tokens=150,  # Reduce max generation length
#     104     repetition_penalty=1.2,  # Avoid repeating words
#     105 )
#     107 # Decode and clean response
#     108 response = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
#
# File ~/anaconda3/envs/python3.9/lib/python3.9/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/python3.9/lib/python3.9/site-packages/transformers/generation/utils.py:2314, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2306     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2307         input_ids=input_ids,
#    2308         expand_size=generation_config.num_return_sequences,
#    2309         is_encoder_decoder=self.config.is_encoder_decoder,
#    2310         **model_kwargs,
#    2311     )
#    2313     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2314     result = self._sample(
#    2315         input_ids,
#    2316         logits_processor=prepared_logits_processor,
#    2317         stopping_criteria=prepared_stopping_criteria,
#    2318         generation_config=generation_config,
#    2319         synced_gpus=synced_gpus,
#    2320         streamer=streamer,
#    2321         **model_kwargs,
#    2322     )
#    2324 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2325     # 11. prepare beam search scorer
#    2326     beam_scorer = BeamSearchScorer(
#    2327         batch_size=batch_size,
#    2328         num_beams=generation_config.num_beams,
#    (...)
#    2333         max_length=generation_config.max_length,
#    2334     )
#
# File ~/anaconda3/envs/python3.9/lib/python3.9/site-packages/transformers/generation/utils.py:3304, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3301 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    3303 if is_prefill:
# -> 3304     outputs = self(**model_inputs, return_dict=True)
#    3305     is_prefill = False
#    3306 else:
#
# File ~/anaconda3/envs/python3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/python3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/python3.9/lib/python3.9/site-packages/transformers/models/idefics3/modeling_idefics3.py:1198, in Idefics3ForConditionalGeneration.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, pixel_values, pixel_attention_mask, image_hidden_states, labels, use_cache, output_attentions, output_hidden_states, cache_position, return_dict, logits_to_keep)
#    1195 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1197 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1198 outputs = self.model(
#    1199     input_ids=input_ids,
#    1200     attention_mask=attention_mask,
#    1201     position_ids=position_ids,
#    1202     past_key_values=past_key_values,
#    1203     inputs_embeds=inputs_embeds,
#    1204     pixel_values=pixel_values,
#    1205     pixel_attention_mask=pixel_attention_mask,
#    1206     image_hidden_states=image_hidden_states,
#    1207     use_cache=use_cache,
#    1208     output_attentions=output_attentions,
#    1209     output_hidden_states=output_hidden_states,
#    1210     cache_position=cache_position,
#    1211     return_dict=return_dict,
#    1212 )
#    1214 hidden_states = outputs[0]
#    1215 # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File ~/anaconda3/envs/python3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/python3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/python3.9/lib/python3.9/site-packages/transformers/models/idefics3/modeling_idefics3.py:1018, in Idefics3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, pixel_values, pixel_attention_mask, image_hidden_states, use_cache, output_attentions, output_hidden_states, cache_position, return_dict)
#    1013     image_hidden_states = image_hidden_states.to(dtype=self.dtype, device=input_ids.device)
#    1015 if past_seen_tokens == 0 and inputs_embeds is not None and image_hidden_states is not None:
#    1016     # When we generate, we don't want to replace the potential image_token_id that we generated by images
#    1017     # that simply don't exist
# -> 1018     inputs_embeds = self.inputs_merger(
#    1019         input_ids=input_ids,
#    1020         inputs_embeds=inputs_embeds,
#    1021         image_hidden_states=image_hidden_states,
#    1022     )
#    1024 outputs = self.text_model(
#    1025     inputs_embeds=inputs_embeds,
#    1026     attention_mask=attention_mask,
#    (...)
#    1033     return_dict=return_dict,
#    1034 )
#    1036 if not return_dict:
#
# File ~/anaconda3/envs/python3.9/lib/python3.9/site-packages/transformers/models/idefics3/modeling_idefics3.py:907, in Idefics3Model.inputs_merger(self, input_ids, inputs_embeds, image_hidden_states)
#     905 # cast to the dtype of the input_embeds to support quantized models
#     906 reshaped_image_hidden_states = reshaped_image_hidden_states.to(inputs_embeds.device, inputs_embeds.dtype)
# --> 907 new_inputs_embeds[special_image_token_mask] = reshaped_image_hidden_states
#     908 return new_inputs_embeds
#
# RuntimeError: shape mismatch: value tensor of shape [10880, 960] cannot be broadcast to indexing result of shape [1951, 960]

# %%
from datasets import load_dataset

ds = load_dataset(path="HuggingFaceTB/smoltalk", name="everyday-conversations")

# %%
import pandas as pd

# Convert train dataset to a DataFrame
df_train = pd.DataFrame(ds['train'])
df_test = pd.DataFrame(ds['test'])

df_train

# %%
df_test
